# %% [markdown]
# ### Week1 - 4 Apr ###

# %% [markdown]
# #### DATATYPES ####

# %%
List = [1,2,3,4] #List can take any value
Tuple = (1,2,3) #Tuples are immutable objects
Set = {1,2,3,4,2,3} #Set cannot have duplicate values
Dict = {1:"Bhavya", 2: "YBIF"} # Dictionary has key-value pairs
print(List,Tuple,Set, Dict)
print(Dict[1]) #Print the value that has key as 1
# Out:
# [1, 2, 3, 4] (1, 2, 3) {1, 2, 3, 4} {1: 'Bhavya', 2: 'YBIF'}
# Bhavya

# %% [markdown]
# #### IMPORT DATA & DATA ANALYSIS ####

# %%
import pandas as pd #import pandas library

# %%
df = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Fruits.csv") #read csv file

# %%
df
# Out:
#     Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0                1      Apple           192          8.4           7.3
# 1                1      Apple           180          8.0           6.8
# 2                1      Apple           176          7.4           7.2
# 3                1      Apple           178          7.1           7.8
# 4                1      Apple           172          7.4           7.0
# 5                1      Apple           166          6.9           7.3
# 6                1      Apple           172          7.1           7.6
# 7                1      Apple           154          7.0           7.1
# 8                1      Apple           164          7.3           7.7
# 9                1      Apple           152          7.6           7.3
# 10               1      Apple           156          7.7           7.1
# 11               1      Apple           156          7.6           7.5
# ...

# %%
df.head() #print first 5 rows
# Out:
#    Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0               1      Apple           192          8.4           7.3
# 1               1      Apple           180          8.0           6.8
# 2               1      Apple           176          7.4           7.2
# 3               1      Apple           178          7.1           7.8
# 4               1      Apple           172          7.4           7.0
#
#    Fruit Colour Score
# 0                0.55
# 1                0.59
# 2                0.60
# 3                0.92
# 4                0.89

# %%
df.tail() #print last 5 rows
# Out:
#     Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 54               3      Lemon            58          6.1           8.5
# 55               3      Lemon            58          6.3           7.7
# 56               3      Lemon            58          5.9           8.1
# 57               3      Lemon            76          6.5           8.5
# 58               3      Lemon            59          6.1           8.1
#
#     Fruit Colour Score
# 54                0.71
# 55                0.72
# 56                0.73
# 57                0.72
# 58                0.70

# %%
df.info() #print concise summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fruit Category      59 non-null     int64
#  1   Fruit Name          59 non-null     object
#  2   Fruit Weight        59 non-null     int64
#  3   Fruit Width         59 non-null     float64
#  4   Fruit Length        59 non-null     float64
#  5   Fruit Colour Score  59 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.9+ KB

# %%
df.describe() #print descriptive statistics
# Out:
#        Fruit Category  Fruit Weight  Fruit Width  Fruit Length  \
# count       59.000000     59.000000    59.000000     59.000000
# mean         1.949153    141.796610     7.105085      7.693220
# std          0.775125     67.335951     0.816938      1.361017
# min          1.000000     58.000000     5.800000      4.000000
# 25%          1.000000     82.000000     6.600000      7.200000
# 50%          2.000000    154.000000     7.200000      7.600000
# 75%          3.000000    167.000000     7.500000      8.200000
# max          3.000000    362.000000     9.600000     10.500000
#
#        Fruit Colour Score
# count           59.000000
# mean             0.762881
# std              0.076857
# min              0.550000
# 25%              0.720000
# 50%              0.750000
# 75%              0.810000
# max              0.930000

# %%
df.shape
# Out:
# (59, 6)

# %%
df.columns #print names of columns
# Out:
# Index(['Fruit Category', 'Fruit Name', 'Fruit Weight', 'Fruit Width',
#        'Fruit Length', 'Fruit Colour Score'],
#       dtype='object')

# %% [markdown]
# ### Week1 - 6 Apr ###

# %% [markdown]
# #### DATA MANIPULATION ####

# %%
titanic = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv")

# %%
titanic.head(2) #print only first 2 rows
# Out:
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
titanic.tail(2) #print only last 2 rows
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1307       3         0  Zakarian, Mr. Ortin  male  27.0      0      0    2670
# 1308       3         0   Zimmerman, Mr. Leo  male  29.0      0      0  315082
#
#        fare cabin embarked boat  body home.dest
# 1307  7.225   NaN        C  NaN   NaN       NaN
# 1308  7.875   NaN        S  NaN   NaN       NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.describe(include = "all") #Include all column irrespective of type of data
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
titanic["age"].nlargest(3) #print first 3 rows ordered by columns in descending order
# Out:
# 14      80.0
# 61      76.0
# 1235    74.0
# Name: age, dtype: float64

# %%
titanic["age"].nsmallest(5) #print first 5 rows ordered by columns in descending order
# Out:
# 763     0.17
# 747     0.33
# 1240    0.42
# 427     0.67
# 657     0.75
# Name: age, dtype: float64

# %%
titanic["age"].astype("object").astype("float64") #Convert the datatype of the column
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
titanic["age"].nunique() #Print total number of unique values in age column
# Out:
# 98

# %%
titanic["age"].unique() #print all the unique values in age column
# Out:
# array([29.  ,  0.92,  2.  , 30.  , 25.  , 48.  , 63.  , 39.  , 53.  ,
#        71.  , 47.  , 18.  , 24.  , 26.  , 80.  ,   nan, 50.  , 32.  ,
#        36.  , 37.  , 42.  , 19.  , 35.  , 28.  , 45.  , 40.  , 58.  ,
#        22.  , 41.  , 44.  , 59.  , 60.  , 33.  , 17.  , 11.  , 14.  ,
#        49.  , 76.  , 46.  , 27.  , 64.  , 55.  , 70.  , 38.  , 51.  ,
#        31.  ,  4.  , 54.  , 23.  , 43.  , 52.  , 16.  , 32.5 , 21.  ,
#        15.  , 65.  , 28.5 , 45.5 , 56.  , 13.  , 61.  , 34.  ,  6.  ,
#        57.  , 62.  , 67.  ,  1.  , 12.  , 20.  ,  0.83,  8.  ,  0.67,
#         7.  ,  3.  , 36.5 , 18.5 ,  5.  , 66.  ,  9.  ,  0.75, 70.5 ,
#        22.5 ,  0.33,  0.17, 40.5 , 10.  , 23.5 , 34.5 , 20.5 , 30.5 ,
#        55.5 , 38.5 , 14.5 , 24.5 , 60.5 , 74.  ,  0.42, 11.5 , 26.5 ])

# %%
titanic["sex"].value_counts() #Print object containing counts of unique values
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
titanic["sex"].replace({"male":0,"female":1}) #Replace male with 0 and  female with 1
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sex, Length: 1309, dtype: int64

# %%
titanic["sex"].replace({"male":0,"female":1}, inplace=True) #Permanently change the data

# %%
titanic["sex"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sex, Length: 1309, dtype: int64

# %%
titanic.loc[3,"name"] #loc uses label to select
# Out:
# 'Allison, Mr. Hudson Joshua Creighton'

# %%
titanic.iloc[3,2] #iloc uses index to select
# Out:
# 'Allison, Mr. Hudson Joshua Creighton'

# %%
titanic.loc[3:6,"name"] #[Row,Column]
# Out:
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                Anderson, Mr. Harry
# 6                  Andrews, Miss. Kornelia Theodosia
# Name: name, dtype: object

# %%
titanic.loc[3:6,["name","boat","age"]]
# Out:
#                                               name boat   age
# 3             Allison, Mr. Hudson Joshua Creighton  NaN  30.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  NaN  25.0
# 5                              Anderson, Mr. Harry    3  48.0
# 6                Andrews, Miss. Kornelia Theodosia   10  63.0

# %%
titanic.iloc[3:7,[2,11,4]]
# Out:
#                                               name boat   age
# 3             Allison, Mr. Hudson Joshua Creighton  NaN  30.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  NaN  25.0
# 5                              Anderson, Mr. Harry    3  48.0
# 6                Andrews, Miss. Kornelia Theodosia   10  63.0

# %%
titanic[(titanic["age"]>70) & (titanic["sex"]==0)] #Conditional statement
# Out:
#       pclass  survived                                  name  sex   age  \
# 9          1         0               Artagaveytia, Mr. Ramon    0  71.0
# 14         1         1  Barkworth, Mr. Algernon Henry Wilson    0  80.0
# 135        1         0             Goldschmidt, Mr. George B    0  71.0
# 727        3         0                  Connors, Mr. Patrick    0  70.5
# 1235       3         0                   Svensson, Mr. Johan    0  74.0
#
#       sibsp  parch    ticket     fare cabin embarked boat   body  \
# 9         0      0  PC 17609  49.5042   NaN        C  NaN   22.0
# 14        0      0     27042  30.0000   A23        S    B    NaN
# 135       0      0  PC 17754  34.6542    A5        C  NaN    NaN
# 727       0      0    370369   7.7500   NaN        Q  NaN  171.0
# 1235      0      0    347060   7.7750   NaN        S  NaN    NaN
#
#                 home.dest
# 9     Montevideo, Uruguay
# 14          Hessle, Yorks
# 135          New York, NY
# 727                   NaN
# ...

# %% [markdown]
# ### Matplotlib ###

# %%
import matplotlib.pyplot as plt #Import matplotlib package

# %%
fig, ax  = plt.subplots()

# %%
fig,ax = plt.subplots(nrows=2,ncols=2, figsize=(14,10), facecolor=[1,0,0])

# %%
x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]
fig,ax=plt.subplots()
ax.plot(x,y,color="red",linewidth=5,linestyle="--") #Print Line Graph
plt.title("Sales")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
fig,ax=plt.subplots()
ax.bar(x,y) #Print Bar Graph
# Out:
# <BarContainer object of 6 artists>

# %%
fig,ax=plt.subplots()
ax.hist(x,y) #Print Histogram
# Out:
# (array([1., 1., 1., 1., 2.]),
#  array([1, 2, 3, 4, 5, 6]),
#  <BarContainer object of 5 artists>)

# %%
fig,ax=plt.subplots()
ax.scatter(x,y) #Print Scatter Plot

# %%
import seaborn as sns

# %%
sns.pairplot(titanic)

# %% [markdown]
# ## Practise Exercise ##

# %% [markdown]
# ### Exercise Vid - 1: Import and Inspect  ##

# %% [markdown]
# Problem 1: Import MPG Dataset as Car Dataframe

# %%
car = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv")

# %% [markdown]
# Problem 2: Print Car Dataframe

# %%
car
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# Problem 3: Inspect first 10 rows

# %%
car.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %% [markdown]
# Problem 4: Inspect last 5 rows

# %%
car.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %% [markdown]
# Problem 5: View all rows

# %%
pd.options.display.max_rows = 400 #Change the maximum rows to show as 400 by default

# %%
car
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %% [markdown]
# Problem 6: How many missing values are there?

# %%
car.isna().sum() #Sum of number of missing values in each column
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# Problem 7: Drop all missing values

# %%
car=car.dropna() #Remove rows which contains missing values

# %%
car.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# Problem 8: Summary Statistics

# %%
car.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Problem 9: Datatype in each column

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# Problem 10: Shape of Dataframe

# %%
car.shape
# Out:
# (392, 9)

# %% [markdown]
# ### Exercise Vid - 2 : Analysing Columns ##

# %% [markdown]
# Problem 1: Import MPG Dataset and store as the pandas dataframe with name mpg

# %%
mpg = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv")

# %% [markdown]
# Problem 2: Copy mpg dataframe as car

# %%
car = mpg.copy() #Copy mpg data to car

# %%
car
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %% [markdown]
# Problem 3: Drop column name cylinders from original dataframe (mpg) and inspect what happened to copy (car)

# %%
mpg=mpg.drop('cylinders',axis=1) #Delete particular column

# %%
mpg.columns
# Out:
# Index(['mpg', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model_year', 'origin', 'name'],
#       dtype='object')

# %%
car.columns #Change in mpg did not reflect in car as car is just a copy of mpg
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# Problem 4: Analyze dataframe car

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
car.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
car.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %% [markdown]
# Problem 5: Provide unique values in each columns cylinders and origin

# %%
car[["cylinders","origin"]].value_counts()
# Out:
# cylinders  origin
# 8          usa       103
# 6          usa        74
# 4          usa        72
#            japan      69
#            europe     63
# 6          japan       6
# 3          japan       4
# 6          europe      4
# 5          europe      3
# dtype: int64

# %% [markdown]
# Problem 6: Provide unique values of column origin

# %%
car["origin"].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %% [markdown]
# Problem 7: Sort value of car dataframe as per displacement column

# %%
car.sort_values("displacement") #Sort values in ascending order
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 117  29.0          4          68.0        49.0    1867          19.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 131  32.0          4          71.0        65.0    1836          21.0
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 144  31.0          4          76.0        52.0    1649          16.5
# 246  32.8          4          78.0        52.0    1985          19.4
# 142  26.0          4          79.0        67.0    1963          15.5
# 343  39.1          4          79.0        58.0    1755          16.9
# 51   30.0          4          79.0        70.0    2074          19.5
# 218  36.0          4          79.0        58.0    1825          18.6
# ...

# %% [markdown]
# Problem 7: Sort value of car dataframe as per displacement column in descending order

# %%
car.sort_values("displacement",ascending=False) #Sort values in descending order
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 8    14.0          8         455.0       225.0    4425          10.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 94   13.0          8         440.0       215.0    4735          11.0
# 90   12.0          8         429.0       198.0    4952          11.5
# 67   11.0          8         429.0       208.0    4633          11.0
# 5    15.0          8         429.0       198.0    4341          10.0
# 39   14.0          8         400.0       175.0    4464          11.5
# 44   13.0          8         400.0       175.0    5140          12.0
# 116  16.0          8         400.0       230.0    4278           9.5
# 63   14.0          8         400.0       175.0    4385          12.0
# ...

# %% [markdown]
# Problem 9: Sort value of car dataframe as per displacement and weight columns in descending order

# %%
car.sort_values(["displacement","weight"],ascending=False) #Sort values in descending order according to particular columns
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 95   12.0          8         455.0       225.0    4951          11.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 94   13.0          8         440.0       215.0    4735          11.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 67   11.0          8         429.0       208.0    4633          11.0
# 5    15.0          8         429.0       198.0    4341          10.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 104  12.0          8         400.0       167.0    4906          12.5
# 43   13.0          8         400.0       170.0    4746          12.0
# ...

# %% [markdown]
# Problem 10: Summary statistics of all columns

# %%
car.describe(include="all")
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %%
car.T #Transpose Dataframe
# Out:
#                                     0                  1    \
# mpg                                18.0               15.0
# cylinders                             8                  8
# displacement                      307.0              350.0
# horsepower                        130.0              165.0
# weight                             3504               3693
# acceleration                       12.0               11.5
# model_year                           70                 70
# origin                              usa                usa
# name          chevrolet chevelle malibu  buick skylark 320
#
#                              2              3            4    \
# mpg                         18.0           16.0         17.0
# cylinders                      8              8            8
# displacement               318.0          304.0        302.0
# horsepower                 150.0          150.0        140.0
# weight                      3436           3433         3449
# ...

# %% [markdown]
# ### Exercise Vid - 3: Indexing and Slicing ###

# %% [markdown]
# Problem 1: Import Titanic dataset and store as the pandas dataframe with name titanic

# %%
titanic = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv")

# %% [markdown]
# Problem 2: Print info of titanic

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# Problem 3: Print column labels

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# Problem 4: Select passenger name column

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %% [markdown]
# Probem 5: Select passenger name column as pandas series and save as name

# %%
print(type(titanic["name"]))
name=titanic["name"]
print(titanic["name"].shape)
print(name)
# Out:
# <class 'pandas.core.series.Series'>
# (1309,)
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %% [markdown]
# Probem 6: Select passenger name column and save as pandas dataframe

# %%
name = pd.DataFrame(titanic["name"])

# %%
name
# Out:
#                                                  name
# 0                       Allen, Miss. Elisabeth Walton
# 1                      Allison, Master. Hudson Trevor
# 2                        Allison, Miss. Helen Loraine
# 3                Allison, Mr. Hudson Joshua Creighton
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                               ...
# 1304                             Zabour, Miss. Hileni
# 1305                            Zabour, Miss. Thamine
# 1306                        Zakarian, Mr. Mapriededer
# 1307                              Zakarian, Mr. Ortin
# 1308                               Zimmerman, Mr. Leo
#
# [1309 rows x 1 columns]

# %%
print(type(name))
print(name.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1309, 1)

# %% [markdown]
# Probem 7: Select 100th row and all columns with iloc function

# %%
titanic.iloc[100,:]
# Out:
# pclass                                                  1
# survived                                                1
# name         Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# sex                                                  male
# age                                                  49.0
# sibsp                                                   1
# parch                                                   0
# ticket                                           PC 17485
# fare                                              56.9292
# cabin                                                 A20
# embarked                                                C
# boat                                                    1
# body                                                  NaN
# home.dest                                  London / Paris
# Name: 100, dtype: object

# %% [markdown]
# Probem 7: Select 100th row loc function

# %%
titanic.loc[100,:]
# Out:
# pclass                                                  1
# survived                                                1
# name         Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# sex                                                  male
# age                                                  49.0
# sibsp                                                   1
# parch                                                   0
# ticket                                           PC 17485
# fare                                              56.9292
# cabin                                                 A20
# embarked                                                C
# boat                                                    1
# body                                                  NaN
# home.dest                                  London / Paris
# Name: 100, dtype: object

# %% [markdown]
# Probem 9: Select all rows with columns label name and fare column with iloc funciton

# %%
titanic.iloc[:,[2,8]]
# Out:
#                                                  name      fare
# 0                       Allen, Miss. Elisabeth Walton  211.3375
# 1                      Allison, Master. Hudson Trevor  151.5500
# 2                        Allison, Miss. Helen Loraine  151.5500
# 3                Allison, Mr. Hudson Joshua Creighton  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...                                               ...       ...
# 1304                             Zabour, Miss. Hileni   14.4542
# 1305                            Zabour, Miss. Thamine   14.4542
# 1306                        Zakarian, Mr. Mapriededer    7.2250
# 1307                              Zakarian, Mr. Ortin    7.2250
# 1308                               Zimmerman, Mr. Leo    7.8750
#
# [1309 rows x 2 columns]

# %% [markdown]
# Probem 10: Select all rows with loc function and column label name and fare

# %%
titanic.loc[:,["name","fare"]]
# Out:
#                                                  name      fare
# 0                       Allen, Miss. Elisabeth Walton  211.3375
# 1                      Allison, Master. Hudson Trevor  151.5500
# 2                        Allison, Miss. Helen Loraine  151.5500
# 3                Allison, Mr. Hudson Joshua Creighton  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...                                               ...       ...
# 1304                             Zabour, Miss. Hileni   14.4542
# 1305                            Zabour, Miss. Thamine   14.4542
# 1306                        Zakarian, Mr. Mapriededer    7.2250
# 1307                              Zakarian, Mr. Ortin    7.2250
# 1308                               Zimmerman, Mr. Leo    7.8750
#
# [1309 rows x 2 columns]

# %% [markdown]
# Probem 11: Select row number 50th, 25th, 15th and column label passenger class, fare, age with both loc and iloc function

# %%
titanic.loc[[50,25,15],["pclass","fare","age"]]
# Out:
#     pclass      fare   age
# 50       1  512.3292  58.0
# 25       1   26.0000  25.0
# 15       1   25.9250   NaN

# %%
titanic.iloc[[50,25,15],[0,8,4]]
# Out:
#     pclass      fare   age
# 50       1  512.3292  58.0
# 25       1   26.0000  25.0
# 15       1   25.9250   NaN

# %% [markdown]
# Probem 12: Select row number from 10th to 25th and column label passenger class, fare, age with both loc and iloc function

# %%
titanic.iloc[10:26,[0,8,4]]
# Out:
#     pclass      fare   age
# 10       1  227.5250  47.0
# 11       1  227.5250  18.0
# 12       1   69.3000  24.0
# 13       1   78.8500  26.0
# 14       1   30.0000  80.0
# 15       1   25.9250   NaN
# 16       1  247.5208  24.0
# 17       1  247.5208  50.0
# 18       1   76.2917  32.0
# 19       1   75.2417  36.0
# 20       1   52.5542  37.0
# 21       1   52.5542  47.0
# 22       1   30.0000  26.0
# 23       1  227.5250  42.0
# 24       1  221.7792  29.0
# 25       1   26.0000  25.0

# %%
titanic.loc[10:25,["pclass","fare","age"]]
# Out:
#     pclass      fare   age
# 10       1  227.5250  47.0
# 11       1  227.5250  18.0
# 12       1   69.3000  24.0
# 13       1   78.8500  26.0
# 14       1   30.0000  80.0
# 15       1   25.9250   NaN
# 16       1  247.5208  24.0
# 17       1  247.5208  50.0
# 18       1   76.2917  32.0
# 19       1   75.2417  36.0
# 20       1   52.5542  37.0
# 21       1   52.5542  47.0
# 22       1   30.0000  26.0
# 23       1  227.5250  42.0
# 24       1  221.7792  29.0
# 25       1   26.0000  25.0

# %% [markdown]
# Probem 13: Select row number from 10th to 15th and columns from passenger class to age with both loc and iloc function

# %%
titanic.loc[10:15,"pclass":"age"]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
#
#        sex   age
# 10    male  47.0
# 11  female  18.0
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 15    male   NaN

# %%
titanic.iloc[10:16,0:5]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
#
#        sex   age
# 10    male  47.0
# 11  female  18.0
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 15    male   NaN

# %% [markdown]
# Probem 13: Select all passengers with age equal to and more than 35 years

# %%
titanic[titanic["age"]>=35]
# Out:
#       pclass  survived                                               name  \
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 23         1         1                              Bidois, Miss. Rosalie
# ...

# %% [markdown]
# Probem 15: Select all passengers with age equal to and more than 35 years and column with label passenger class to age

# %%
titanic.loc[(titanic["age"]>=35),"pclass":"age"]
# Out:
#       pclass  survived                                               name  \
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 23         1         1                              Bidois, Miss. Rosalie
# ...

# %% [markdown]
# Probem 16: Select all female passengers with age equal to and more than 35 years

# %%
titanic.loc[(titanic["age"]>=35)&(titanic["sex"]=="female"),]
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 23         1         1                              Bidois, Miss. Rosalie
# 28         1         1                             Bissette, Miss. Amelia
# 33         1         1                           Bonnell, Miss. Elizabeth
# 35         1         1                           Bowen, Miss. Grace Scott
# 41         1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 42         1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43         1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44         1         1                    Burns, Miss. Elizabeth Margaret
# ...

# %% [markdown]
# ### Exercise Vid - 4 : Calculated Columns ###

# %% [markdown]
# Probem 1: Import Tips dataset and store as the pandas dataframe with name tips

# %%
tips = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Tips%20Payment%20Data.csv")

# %% [markdown]
# Probem 2: Display the first 5 rows of tips dataframe

# %%
tips.head()
# Out:
#    Total Bill   Tip  Gender Smoker  Day    Time  Size  Bill Per Person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971320    Sun4458
# 3    Nathaniel Harris  4676137647685990    Sun5260
# 4        Tonya Carter  4832732618637220    Sun2251

# %% [markdown]
# Probem 3: Calculate percentage of tip to the total bill

# %%
(tips["Tip"]/tips["Total Bill"])*100
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
# 5      18.623962
# 6      22.805017
# 7      11.607143
# 8      13.031915
# 9      21.853857
# 10     16.650438
# 11     14.180374
# 12     10.181582
# 13     16.277808
# 14     20.364127
# 15     18.164968
# 16     16.166505
# 17     22.774708
# 18     20.624632
# 19     16.222760
# 20     22.767857
# 21     13.553475
# 22     14.140774
# 23     19.228818
# 24     16.044400
# 25     13.138686
# 26     14.958863
# 27     15.760441
# 28     19.815668
# 29     15.267176
# 30     15.183246
# 31     13.623978
# 32     19.920319
# 33     11.841469
# 34     18.391451
# 35     14.962594
# 36     12.262416
# 37     18.133491
# 38     12.359551
# 39     15.989767
# 40     13.965087
# 41     14.547537
# 42     21.951220
# 43     13.636364
# 44     18.421053
# 45     16.402406
# 46     22.492128
# 47     18.518519
# 48      7.180385
# 49     16.629712
# 50     19.936204
# 51     25.267250
# ...

# %%
tip_percentage=(tips["Tip"]/tips["Total Bill"])*100

# %%
tip_percentage
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
# 5      18.623962
# 6      22.805017
# 7      11.607143
# 8      13.031915
# 9      21.853857
# 10     16.650438
# 11     14.180374
# 12     10.181582
# 13     16.277808
# 14     20.364127
# 15     18.164968
# 16     16.166505
# 17     22.774708
# 18     20.624632
# 19     16.222760
# 20     22.767857
# 21     13.553475
# 22     14.140774
# 23     19.228818
# 24     16.044400
# 25     13.138686
# 26     14.958863
# 27     15.760441
# 28     19.815668
# 29     15.267176
# 30     15.183246
# 31     13.623978
# 32     19.920319
# 33     11.841469
# 34     18.391451
# 35     14.962594
# 36     12.262416
# 37     18.133491
# 38     12.359551
# 39     15.989767
# 40     13.965087
# 41     14.547537
# 42     21.951220
# 43     13.636364
# 44     18.421053
# 45     16.402406
# 46     22.492128
# 47     18.518519
# 48      7.180385
# 49     16.629712
# 50     19.936204
# 51     25.267250
# ...

# %% [markdown]
# Probem 4: Create a new column of percentage tip

# %%
tip_percentage=tips["Tip"]/tips["Total Bill"]*100
tip_percentage
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
# 5      18.623962
# 6      22.805017
# 7      11.607143
# 8      13.031915
# 9      21.853857
# 10     16.650438
# 11     14.180374
# 12     10.181582
# 13     16.277808
# 14     20.364127
# 15     18.164968
# 16     16.166505
# 17     22.774708
# 18     20.624632
# 19     16.222760
# 20     22.767857
# 21     13.553475
# 22     14.140774
# 23     19.228818
# 24     16.044400
# 25     13.138686
# 26     14.958863
# 27     15.760441
# 28     19.815668
# 29     15.267176
# 30     15.183246
# 31     13.623978
# 32     19.920319
# 33     11.841469
# 34     18.391451
# 35     14.962594
# 36     12.262416
# 37     18.133491
# 38     12.359551
# 39     15.989767
# 40     13.965087
# 41     14.547537
# 42     21.951220
# 43     13.636364
# 44     18.421053
# 45     16.402406
# 46     22.492128
# 47     18.518519
# 48      7.180385
# 49     16.629712
# 50     19.936204
# 51     25.267250
# ...

# %% [markdown]
# Problem 5: Insert percentage tip in existing tips dataframe

# %%
tips["tip_percentage"]=((tips["Tip"]/tips["Total Bill"])*100)

# %%
tips.head()
# Out:
#    Total Bill   Tip  Gender Smoker  Day    Time  Size  Bill Per Person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971320    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685990    Sun5260       13.978041
# 4        Tonya Carter  4832732618637220    Sun2251       14.680765

# %% [markdown]
# Problem 6: Round upto one decimal place the tip_percentage column values

# %%
tips["tip_percentage"]=((tips["Tip"]/tips["Total Bill"])*100).round(1)
tips.head()
# Out:
#    Total Bill   Tip  Gender Smoker  Day    Time  Size  Bill Per Person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959             5.9
# 1      Douglas Tucker  4478071379779230    Sun4608            16.1
# 2      Travis Walters  6011812112971320    Sun4458            16.7
# 3    Nathaniel Harris  4676137647685990    Sun5260            14.0
# 4        Tonya Carter  4832732618637220    Sun2251            14.7

# %% [markdown]
# Problem 7: Drop column Player Name

# %%
tips.drop("Payer Name",axis=1)
tips.head()
# Out:
#    Total Bill   Tip  Gender Smoker  Day    Time  Size  Bill Per Person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959             5.9
# 1      Douglas Tucker  4478071379779230    Sun4608            16.1
# 2      Travis Walters  6011812112971320    Sun4458            16.7
# 3    Nathaniel Harris  4676137647685990    Sun5260            14.0
# 4        Tonya Carter  4832732618637220    Sun2251            14.7

# %% [markdown]
# Problem 8: Index tips dataframe as per Payment ID

# %%
tips.set_index("Payment ID")
# Out:
#             Total Bill    Tip  Gender Smoker   Day    Time  Size  \
# Payment ID
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34   1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01   3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68   3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59   3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29   4.71    Male     No   Sun  Dinner     4
# Sun5985           8.77   2.00    Male     No   Sun  Dinner     2
# Sun8157          26.88   3.12    Male     No   Sun  Dinner     4
# Sun6820          15.04   1.96    Male     No   Sun  Dinner     2
# Sun3775          14.78   3.23    Male     No   Sun  Dinner     2
# Sun2546          10.27   1.71    Male     No   Sun  Dinner     2
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sun1300          15.42   1.57    Male     No   Sun  Dinner     2
# ...

# %%
tips.head()
# Out:
#    Total Bill   Tip  Gender Smoker  Day    Time  Size  Bill Per Person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959             5.9
# 1      Douglas Tucker  4478071379779230    Sun4608            16.1
# 2      Travis Walters  6011812112971320    Sun4458            16.7
# 3    Nathaniel Harris  4676137647685990    Sun5260            14.0
# 4        Tonya Carter  4832732618637220    Sun2251            14.7

# %% [markdown]
# Problem 9: Change index tips dataframe as per Payment ID

# %%
tips = tips.set_index("Payment ID")
tips.head()
# Out:
#             Total Bill   Tip  Gender Smoker  Day    Time  Size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             Bill Per Person          Payer Name         CC Number  \
# Payment ID
# Sun2959                8.49  Christy Cunningham  3560325168603410
# Sun4608                3.45      Douglas Tucker  4478071379779230
# Sun4458                7.00      Travis Walters  6011812112971320
# Sun5260               11.84    Nathaniel Harris  4676137647685990
# Sun2251                6.15        Tonya Carter  4832732618637220
#
#             tip_percentage
# Payment ID
# Sun2959                5.9
# Sun4608               16.1
# Sun4458               16.7
# Sun5260               14.0
# ...

# %% [markdown]
# Problem 10: Reset index of tips dataframe to row index

# %%
tips=tips.reset_index()

# %%
tips.head()
# Out:
#   Payment ID  Total Bill   Tip  Gender Smoker  Day    Time  Size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    Bill Per Person          Payer Name         CC Number  tip_percentage
# 0             8.49  Christy Cunningham  3560325168603410             5.9
# 1             3.45      Douglas Tucker  4478071379779230            16.1
# 2             7.00      Travis Walters  6011812112971320            16.7
# 3            11.84    Nathaniel Harris  4676137647685990            14.0
# 4             6.15        Tonya Carter  4832732618637220            14.7
